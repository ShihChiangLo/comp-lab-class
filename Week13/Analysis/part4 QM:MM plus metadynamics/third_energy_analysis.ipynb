# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mdtraj as md
import matplotlib
from matplotlib.animation import FFMpegWriter, PillowWriter

# %%
#data from meta reaction coordinate
file = pd.read_csv('./METADYN-COLVAR.metadynLog',skiprows=1,sep='\s+',header=None)
file.columns = ['Time','Energy','X','Y','z','K']

# %%
plt.plot(file.Time, file.Energy,label='energy')
plt.xlabel('reaction')
plt.ylabel('d(C5663-C5675)-d(O5670-C5671)')
plt.title('Reaction coordinate')
plt.legend()
plt.savefig('Reaction coordinate.pdf')
plt.show()
